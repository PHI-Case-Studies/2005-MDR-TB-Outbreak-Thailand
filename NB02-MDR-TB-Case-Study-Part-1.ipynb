# %%
# %run ./resources/library.py
style_notebook()
# Out:
# <style>
# div.text_cell_render { /* Customize text cells */
#     font-family: 'Arial';
#     font-size:20px;
#     line-height: 1.5em;
#     padding-left:3em;
#     padding-right:3em;
# }
# .CodeMirror {
#     font-family:  'Source Code Pro', monospace;
#     font-size: 18px;
# }
#
# /* Cell output */
#
# .rendered_html pre, .rendered_html code {
#     color: inherit !important;
#     background-color: inherit !important;
# }
# div.output_area pre {
#     line-height: 1.2em;
#     color: #93a1a1 !important;
#     font-family: 'Source Code Pro', monospace;
#     font-size: 16px;
# }
# .rendered_html table, .rendered_html td, .rendered_html th {
#     border: 1px solid #586e75 !important;
#     font-family: 'Arial';
#     font-size: 16px;
# }
# </style>

# %% [markdown]
# Digital Case Study: Multidrug-Resistant Tuberculosis (MDR-TB) Outbreak - Revisiting the 2005 Outbreak Investigation in Thailand by John Oeltmann

# %% [markdown]
# # Part 1: Mapping the 2005 MDR-TB Outbreak in Thailand

# %% [markdown]
# The Oeltmann et. al (2005) paper describes an outbreak of MDR-TB within a refugee camp in Thailand during 2005.  You may notice some similarities between the work-flow pattern to map this outbreak with that of Dr. John Snow as he worked on the Cholera outbreak in London.

# %%
show_pdf('resources/genotyping.pdf',900,600)
# Out:
# <object data='resources/genotyping.pdf' width=900 height=600></object>

# %% [markdown]
# For Notebooks 2 and 3, we will follow the workflow outlined in this PDf file below.

# %%
show_pdf("./resources/Work_flow_diagram_08012017.pdf",800,500)
# Out:
# <object data='./resources/Work_flow_diagram_08012017.pdf' width=800 height=500></object>

# %% [markdown]
# ## Step 1. Outbreak Notification

# %% [markdown]
# You just received the **notification** below of an outbreak by email.

# %% [markdown]
# Please download the notification from your email (PDF attachment) using the PDF below. Please take time to read the contents of the attachment.

# %%
show_pdf("./resources/GDD.pdf",800,500)
# Out:
# <object data='./resources/GDD.pdf' width=800 height=500></object>

# %% [markdown]
# ![2005 Worldwide Incidence of TB](./images/Incidence-of-TB-worldwide-2005-WHO.png)
#
# **Figure 1**.

# %% [markdown]
# ##  Step 2. Initial Cases Received

# %% [markdown]
# You then received a separate email with an attached [Excel Spreadsheet](./resources/Thailand_cases_exercise_1st_spreadsheet_07232017.xls) that contains data about the initial cases.

# %% [markdown]
# Now it's time to use your data science hacking skills. Using Python code, read this spreadsheet as a data frame to use within the Jupyter Notebooks environment.

# %%
import pandas as pd

# %%
# Import the excel file and call it xls_file
xls_file = pd.ExcelFile('resources/Thailand_cases_exercise_1st_spreadsheet_07232017.xls')
xls_file

# %%
# View the excel file's sheet names
xls_file.sheet_names
# Out:
# ['TBDATA']

# %%
# Load the xls file's Sheet1 as a dataframe
df1 = xls_file.parse('TBDATA')

# %%
# To view the column names with some data we can use the "head" function and indicate we want to display only 4 rows (the top 4).
# You can change the number 4 to something else, try it.
df1.head(4)
# Out:
#       CaseNo         LON        LAT                COORDS
# 0  TH-102678  100.828607  14.704461  14.704461,100.828607
# 1  TH-101007  100.829347  14.702266  14.702266,100.829347
# 2  TH-101290  100.825159  14.699828  14.699828,100.825159
# 3  TH-101067  100.824887  14.700197  14.700197,100.824887

# %% [markdown]
# You can also read the Excel file [here](./resources/Thailand_cases_exercise_1st_spreadsheet_07232017.xls) to check the outputs above.

# %% [markdown]
# > Question 1. What are the column names in the Excel spreadsheet?

# %% [markdown]
# Answer Cell for Question #1.
# Please type your answer below. Double-click to begin typing.

# %% [markdown]
# > Question 2. What is the name of the Sheet where the data are found?

# %% [markdown]
# > Question 3. How do you list the columns of the dataframe `df1`?

# %%
# For Question #3, you may want to try typing the code here...
# Try: list(df1) or df1.columns.values

# %% [markdown]
# Let's "pickle" this data frame so we can retrieve it later.

# %%
df1.to_pickle("outputs/df1.pickle")

# %% [markdown]
# ## Step 3. Mapping the Cases (data) in the Spreadsheet

# %%
# use folium
import folium

# %%
#Store the coordinates of the refugee camp listed in the EOC email
CAMP_COORDINATES = (14.699859, 100.829019)

# %%
# create empty map zoomed in on Refugee camp
map1 = folium.Map(location=CAMP_COORDINATES, zoom_start=16)

# %%
# Let's see what this map looks like...
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Let's add a marker for every record in the filtered data, use a clustered view
for each in df1.iterrows():
    folium.Marker([each[1]['LAT'],each[1]['LON']], popup=each[1]['CaseNo']).add_to(map1)

# %%
# Let's display the map again!                                       
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can click on each marker in the map above to launch the pop-up that displays the case number.

# %% [markdown]
# ## Step 4. Learning about Genotyping Terminology

# %% [markdown]
# The data received include a unique identifier for each case within the line listing. This may not always be present in real-life outbreak data, but is very helpful. We will be using this ID to join data from various sources, including molecular epidemiology data with genotypes of TB isolates. The CDC documentation on genotyping can help you to better understand the molecular epi data.

# %% [markdown]
# In a separate email, you receive Study IDs and genotypes within a 24-loci MIRU-VNTR coded system. You can read the genotyping documentation [here](./resources/genotypingterminology.pdf). Please take some time to understand the terminology used.

# %% [markdown]
# ## Step 5. Data Update from the Field!

# %% [markdown]
# You receive an email from the field with genotyping data in an [Excel spreadsheet](./resources/Thailand_cases_exercise_2nd_spreadsheet_07232017.xls). This spreadsheet includes the unique ID for the patient and a 24-loci MIRU-VNTR string code as described in the CDC genotyping documentation. We will read this spreadsheet into a data frame in a similar manner to the case line listing data. Please run the Python code below to read the genotyping data.

# %%
# Import the excel file and call it xls_file
xls_file2 = pd.ExcelFile('resources/Thailand_cases_exercise_2nd_spreadsheet_07232017.xls')
xls_file2

# %%
# View the excel file's sheet names
xls_file2.sheet_names
# Out:
# ['TBDATA2']

# %%
# Load the xls file's Sheet1 as a dataframe
df2 = xls_file2.parse('TBDATA2')

# %%
# Let's display the dataframe
df2
# Out:
#         CaseNo              FAKEMIRUVNTR  FAKEMIRUID         SYMBOL
# 0    TH-102678  012345678901234567893120           3    Blue Circle
# 1    TH-101007  012345678901234567894320           4   Green Circle
# 2    TH-101290  012345678901234567894320           4   Green Circle
# 3    TH-101067  012345678901234567894320           4   Green Circle
# 4    TH-101184  012345678901234567890423           5   Green Circle
# 5    TH-100913  012345678901234567893120           3   Green Circle
# 6    TH-101176  012345678901234567894320           4   Green Circle
# 7    TH-101497  012345678901234567894320           4   Green Circle
# 8    TH-101280  012345678901234567894320           4    Blue Circle
# 9    TH-101055  012345678901234567894320           4   Green Circle
# 10   TH-100864  012345678901234567894320           4   Green Circle
# 11   TH-101271  012345678901234567894320           4   Green Circle
# 12   TH-101353  012345678901234567894320           4   Green Circle
# 13   TH-101384  012345678901234567893120           3    Blue Circle
# 14   TH-101439  012345678901234567894320           4   Green Circle
# 15   TH-101034  012345678901234567894320           4   Green Circle
# 16   TH-101039  012345678901234567894320           4   Green Circle
# 17   TH-101275  012345678901234567894320           4   Green Circle
# 18   TH-101276  012345678901234567894320           4   Green Circle
# 19   TH-101553  012345678901234567894320           4   Green Circle
# 20   TH-101291  012345678901234567894320           4   Green Circle
# 21   TH-101579  012345678901234567890123           1   Red Triangle
# 22   TH-101404  012345678901234567894320           4   Green Circle
# 23   TH-101598  012345678901234567894320           4   Green Circle
# 24   TH-101631  012345678901234567894320           4   Green Circle
# 25   TH-101343  012345678901234567894320           4   Green Circle
# 26   TH-100877  012345678901234567894320           4   Green Circle
# 27   TH-101829  012345678901234567894320           4   Green Circle
# 28   TH-101647  012345678901234567894320           4   Green Circle
# 29   TH-101637  012345678901234567894320           4   Green Circle
# ..         ...                       ...         ...            ...
# 185  TH-103728  012345678901234567894320           4   Green Circle
# 186  TH-103611  012345678901234567894320           4    Blue Circle
# 187  TH-103910  012345678901234567890213           2  Yellow Square
# 188  TH-103916  012345678901234567894320           4   Green Circle
# 189  TH-101942  012345678901234567894320           4   Green Circle
# 190  TH-101964  012345678901234567893120           3    Blue Circle
# 191  TH-104120  012345678901234567894320           4   Green Circle
# 192  TH-103452  012345678901234567894320           4   Green Circle
# 193  TH-104141  012345678901234567894320           4   Green Circle
# 194  TH-104039  012345678901234567890123           1   Red Triangle
# 195  TH-103744  012345678901234567894320           4   Green Circle
# 196  TH-103814  012345678901234567894320           4   Green Circle
# 197  TH-103386  012345678901234567894320           4  Yellow Square
# 198  TH-104133  012345678901234567894320           4   Green Circle
# 199  TH-102166  012345678901234567894320           4   Green Circle
# 200  TH-104026  012345678901234567894320           4   Green Circle
# 201  TH-104166  012345678901234567894320           4   Green Circle
# 202  TH-104152  012345678901234567894320           4   Green Circle
# 203  TH-103890  012345678901234567894320           4   Green Circle
# 204  TH-102065  012345678901234567894320           4   Green Circle
# 205  TH-102047  012345678901234567894320           4   Green Circle
# 206  TH-102258  012345678901234567894320           4   Green Circle
# 207  TH-102076  012345678901234567894320           4   Green Circle
# 208  TH-102527  012345678901234567894320           4   Green Circle
# 209  TH-102295  012345678901234567894320           4   Green Circle
# 210  TH-101970  012345678901234567894320           4   Green Circle
# 211  TH-103698  012345678901234567894320           4   Green Circle
# 212  TH-103927  012345678901234567890123           1   Red Triangle
# 213  TH-102661  012345678901234567894320           4   Green Circle
# 214  TH-103886  012345678901234567894320           4   Green Circle
#
# [215 rows x 4 columns]

# %%
# Display the first four records of the dataframe df2
# Type the command below and press, Shift-Enter

# %% [markdown]
# Note that we have pre-assigned symbols in the last column to facilitate the visualization of different types of data on a map.

# %%
# Let's pickle this dataframe and use it later
df2.to_pickle("outputs/df2.pickle")

# %% [markdown]
# ## Step 6. Merging Two Data Sets

# %% [markdown]
# In the steps above, we you have created two dataframes:
# 1. `df1`: Line listing of cases
# 2. `df2`: Cases with MIRU-VNTR (genotyping) string code

# %% [markdown]
# Next we will need to **`merge`** the case-line listing data with the genotyping data to create an analytic dataset with cases and their genotypes. In this step we will join the case-line listing data with the genotyping data and creating the analytic dataset, using the `CaseNo` field as the linking variable. Please run the Python code below, using `pandas merge` to merge these data:

# %%
# Merge the dataframe with case-line listed data with the data frame with genotyping data...
df3 = pd.merge(df1, df2, left_on='CaseNo', right_on='CaseNo')
df3
# Out:
#         CaseNo         LON        LAT                COORDS  \
# 0    TH-102678  100.828607  14.704461  14.704461,100.828607
# 1    TH-101007  100.829347  14.702266  14.702266,100.829347
# 2    TH-101290  100.825159  14.699828  14.699828,100.825159
# 3    TH-101067  100.824887  14.700197  14.700197,100.824887
# 4    TH-101184  100.829032  14.697482  14.697482,100.829032
# 5    TH-100913  100.829261  14.702418  14.702418,100.829261
# 6    TH-101176  100.829228  14.702959  14.702959,100.829228
# 7    TH-101497  100.829140  14.702244   14.702244,100.82914
# 8    TH-101280  100.829344  14.702908  14.702908,100.829344
# 9    TH-101055  100.829494  14.701485  14.701485,100.829494
# 10   TH-100864  100.829138  14.702186  14.702186,100.829138
# 11   TH-101271  100.829373  14.697514  14.697514,100.829373
# 12   TH-101353  100.829002  14.696928  14.696928,100.829002
# 13   TH-101384  100.829405  14.701287  14.701287,100.829405
# 14   TH-101439  100.829420  14.697212   14.697212,100.82942
# 15   TH-101034  100.826055  14.699706  14.699706,100.826055
# 16   TH-101039  100.829447  14.701043  14.701043,100.829447
# 17   TH-101275  100.829181  14.703556  14.703556,100.829181
# 18   TH-101276  100.829240  14.702800     14.7028,100.82924
# 19   TH-101553  100.828362  14.702821  14.702821,100.828362
# 20   TH-101291  100.825530  14.700395   14.700395,100.82553
# 21   TH-101579  100.828440  14.702731   14.702731,100.82844
# 22   TH-101404  100.828832  14.702595  14.702595,100.828832
# 23   TH-101598  100.825984  14.699475  14.699475,100.825984
# 24   TH-101631  100.825801  14.699378  14.699378,100.825801
# 25   TH-101343  100.829483  14.701389  14.701389,100.829483
# 26   TH-100877  100.830114  14.701636  14.701636,100.830114
# 27   TH-101829  100.828806  14.700165  14.700165,100.828806
# 28   TH-101647  100.829316  14.700580   14.70058,100.829316
# 29   TH-101637  100.829062  14.700601  14.700601,100.829062
# ..         ...         ...        ...                   ...
# 185  TH-103728  100.831390  14.700485   14.700485,100.83139
# 186  TH-103611  100.830703  14.697945  14.697945,100.830703
# 187  TH-103910  100.828075  14.700496  14.700496,100.828075
# 188  TH-103916  100.830104  14.699881  14.699881,100.830104
# 189  TH-101942  100.829720  14.700271   14.700271,100.82972
# 190  TH-101964  100.829418  14.703223  14.703223,100.829418
# 190  012345678901234567893120           3    Blue Circle
# 191  012345678901234567894320           4   Green Circle
# 192  012345678901234567894320           4   Green Circle
# 193  012345678901234567894320           4   Green Circle
# 194  012345678901234567890123           1   Red Triangle
# 195  012345678901234567894320           4   Green Circle
# 196  012345678901234567894320           4   Green Circle
# 197  012345678901234567894320           4  Yellow Square
# 198  012345678901234567894320           4   Green Circle
# 199  012345678901234567894320           4   Green Circle
# 200  012345678901234567894320           4   Green Circle
# 201  012345678901234567894320           4   Green Circle
# 202  012345678901234567894320           4   Green Circle
# 203  012345678901234567894320           4   Green Circle
# 204  012345678901234567894320           4   Green Circle
# 205  012345678901234567894320           4   Green Circle
# 206  012345678901234567894320           4   Green Circle
# 207  012345678901234567894320           4   Green Circle
# 208  012345678901234567894320           4   Green Circle
# 209  012345678901234567894320           4   Green Circle
# 210  012345678901234567894320           4   Green Circle
# 211  012345678901234567894320           4   Green Circle
# 212  012345678901234567890123           1   Red Triangle
# 213  012345678901234567894320           4   Green Circle
# 214  012345678901234567894320           4   Green Circle
#
# [215 rows x 7 columns]

# %%
df3.to_pickle("outputs/df3.pickle")

# %% [markdown]
# ## Step 7. Mapping the Merged Data Sets

# %% [markdown]
# Please create a map of the TB cases, colored by MIRU-ID from merged df and df2

# %%
# create 2nd map of the case data 
#Store the coordinates of the refugee camp listed in the EOC email
CAMP_COORDINATES = (14.699859, 100.829019)

# create empty map zoomed in on Refugee camp
map2 = folium.Map(location=CAMP_COORDINATES, zoom_start=16)
# store the latitude and longitude coordinates from the data frame

for each in df3.iterrows():
        # we change the color of the marker based on MIRUID
        if each[1]['FAKEMIRUID']== 4:                     
            folium.Marker([each[1]['LAT'],each[1]['LON']], \
                          popup=each[1]['CaseNo'], \
                          icon=folium.Icon(color='green')).add_to(map2)
        if each[1]['FAKEMIRUID']== 3:                     
            folium.Marker([each[1]['LAT'],each[1]['LON']], \
                          popup=each[1]['CaseNo'], \
                          icon=folium.Icon(color='blue')).add_to(map2)
        if each[1]['FAKEMIRUID']== 2:                     
            folium.Marker([each[1]['LAT'],each[1]['LON']], \
                          popup=each[1]['CaseNo'], \
                          icon=folium.Icon(color='yellow')).add_to(map2)
        if each[1]['FAKEMIRUID']== 1:                     
            folium.Marker([each[1]['LAT'],each[1]['LON']], \
                          popup=each[1]['CaseNo'], \
                          icon=folium.Icon(color='red')).add_to(map2)           
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 8. Mapping by Drug Resistance Type

# %% [markdown]
# Now that we have successfully joined the case line listing data with the genotyping data and created the analytic dataset, we will create a map of the genotyped cases and symbolize these cases by drug-resistance type.

# %% [markdown]
# We receive an email, our [third spreadsheet attached](./resources/Thailand_cases_exercise_3rd_spreadsheet_07232017.xls), that includes a MIRU-ID and **classification of MIRU-ID by drug-resistance type**. We need to create a new field in the analytic dataset for DRTYPE and code each line-listed case by this type.

# %% [markdown]
# Please run the Python code below to classify the MIRU-IDs by DRTYPE.

# %%
# read the 3rd spreadsheet with MIRU-IDs and DRTYPE and create a data frame
# Import the excel file and call it xls_file
xls_file3 = pd.ExcelFile('resources/Thailand_cases_exercise_3rd_spreadsheet_07232017.xls')
xls_file3

# %%
# View the excel file's sheet names
xls_file3.sheet_names
# Out:
# ['TBDATA3']

# %%
# Load the xls file's Sheet1 as a dataframe
df4 = xls_file3.parse('TBDATA3')
df4
df4.to_pickle("outputs/df3.pickle")

# %%
df3.head(4)
# Out:
#       CaseNo         LON        LAT                COORDS  \
# 0  TH-102678  100.828607  14.704461  14.704461,100.828607
# 1  TH-101007  100.829347  14.702266  14.702266,100.829347
# 2  TH-101290  100.825159  14.699828  14.699828,100.825159
# 3  TH-101067  100.824887  14.700197  14.700197,100.824887
#
#                FAKEMIRUVNTR  FAKEMIRUID        SYMBOL
# 0  012345678901234567893120           3   Blue Circle
# 1  012345678901234567894320           4  Green Circle
# 2  012345678901234567894320           4  Green Circle
# 3  012345678901234567894320           4  Green Circle

# %%
df4.head(4)
# Out:
#       CaseNo              FAKEMIRUVNTR  FAKEMIRUID          DRTYPE
# 0  TH-102678  012345678901234567893120           3  PANSUSCEPTIBLE
# 1  TH-101007  012345678901234567894320           4         UNKNOWN
# 2  TH-101290  012345678901234567894320           4         UNKNOWN
# 3  TH-101067  012345678901234567894320           4         UNKNOWN

# %%
# merge the dataframe with DRTYPE with the previous merge to form the analytic dataset
df5 = pd.merge(df4, df3, left_on='CaseNo', right_on='CaseNo')
df5
# Out:
#         CaseNo            FAKEMIRUVNTR_x  FAKEMIRUID_x  \
# 0    TH-102678  012345678901234567893120             3
# 1    TH-101007  012345678901234567894320             4
# 2    TH-101290  012345678901234567894320             4
# 3    TH-101067  012345678901234567894320             4
# 4    TH-101184  012345678901234567890423             5
# 5    TH-100913  012345678901234567893120             3
# 6    TH-101176  012345678901234567894320             4
# 7    TH-101497  012345678901234567894320             4
# 8    TH-101280  012345678901234567894320             4
# 9    TH-101055  012345678901234567894320             4
# 10   TH-100864  012345678901234567894320             4
# 11   TH-101271  012345678901234567894320             4
# 12   TH-101353  012345678901234567894320             4
# 13   TH-101384  012345678901234567893120             3
# 14   TH-101439  012345678901234567894320             4
# 15   TH-101034  012345678901234567894320             4
# 16   TH-101039  012345678901234567894320             4
# 17   TH-101275  012345678901234567894320             4
# 18   TH-101276  012345678901234567894320             4
# 19   TH-101553  012345678901234567894320             4
# 20   TH-101291  012345678901234567894320             4
# 21   TH-101579  012345678901234567890123             1
# 22   TH-101404  012345678901234567894320             4
# 23   TH-101598  012345678901234567894320             4
# 24   TH-101631  012345678901234567894320             4
# 25   TH-101343  012345678901234567894320             4
# 26   TH-100877  012345678901234567894320             4
# 27   TH-101829  012345678901234567894320             4
# 28   TH-101647  012345678901234567894320             4
# 29   TH-101637  012345678901234567894320             4
# ..         ...                       ...           ...
# 185  TH-103728  012345678901234567894320             4
# 186  TH-103611  012345678901234567894320             4
# 187  TH-103910  012345678901234567890213             2
# 188  TH-103916  012345678901234567894320             4
# 189  TH-101942  012345678901234567894320             4
# 190  TH-101964  012345678901234567893120             3
# 196  14.698538,100.829602  012345678901234567894320             4
# 197  14.698524,100.829324  012345678901234567894320             4
# 198  14.697969,100.830434  012345678901234567894320             4
# 199  14.700713,100.827291  012345678901234567894320             4
# 200  14.697325,100.830123  012345678901234567894320             4
# 201  14.697718,100.831054  012345678901234567894320             4
# 202  14.696539,100.830275  012345678901234567894320             4
# 203  14.699906,100.828363  012345678901234567894320             4
# 204  14.700093,100.827877  012345678901234567894320             4
# 205  14.699738,100.829123  012345678901234567894320             4
# 206  14.701054,100.830704  012345678901234567894320             4
# 207   14.701603,100.83001  012345678901234567894320             4
# 208   14.699632,100.82986  012345678901234567894320             4
# 209  14.701271,100.830962  012345678901234567894320             4
# 210  14.700693,100.828073  012345678901234567894320             4
# 211  14.699712,100.829368  012345678901234567894320             4
# 212  14.700072,100.829917  012345678901234567890123             1
# 213  14.704341,100.828381  012345678901234567894320             4
# 214   14.70003,100.828146  012345678901234567894320             4
#
#             SYMBOL
# 0      Blue Circle
# 1     Green Circle
# 2     Green Circle
# 3     Green Circle
# 4     Green Circle
# 5     Green Circle
# 6     Green Circle
# 7     Green Circle
# 8      Blue Circle
# 9     Green Circle
# 10    Green Circle
# 11    Green Circle
# 12    Green Circle
# 13     Blue Circle
# 14    Green Circle
# 15    Green Circle
# 16    Green Circle
# 17    Green Circle
# 18    Green Circle
# 19    Green Circle
# 20    Green Circle
# 21    Red Triangle
# 22    Green Circle
# 23    Green Circle
# 24    Green Circle
# 25    Green Circle
# 26    Green Circle
# 27    Green Circle
# 28    Green Circle
# 29    Green Circle
# ..             ...
# 185   Green Circle
# 186    Blue Circle
# 187  Yellow Square
# 188   Green Circle
# 189   Green Circle
# 190    Blue Circle
# 191   Green Circle
# 192   Green Circle
# 193   Green Circle
# 194   Red Triangle
# 195   Green Circle
# 196   Green Circle
# 197  Yellow Square
# 198   Green Circle
# 199   Green Circle
# 200   Green Circle
# 201   Green Circle
# 202   Green Circle
# 203   Green Circle
# 204   Green Circle
# 205   Green Circle
# 206   Green Circle
# 207   Green Circle
# 208   Green Circle
# 209   Green Circle
# 210   Green Circle
# 211   Green Circle
# 212   Red Triangle
# 213   Green Circle
# 214   Green Circle
#
# [215 rows x 10 columns]

# %% [markdown]
# ## Step 9. Mapping the Analytic Data Set

# %% [markdown]
# Next, we will create a map of the analytic dataset with genotyped TB cases, symbolized by drug-resistance type. We wish to see a map of the cases within the refugee camp and to examine the types of TB within the camp, including MDR-TB cases. Please run the code below to create the map of TB cases within the camp:

# %%
# create 3rd map of the case data 
#Store the coordinates of the refugee camp listed in the EOC email
CAMP_COORDINATES = (14.699859, 100.829019)

# create empty map zoomed in on Refugee camp
map3 = folium.Map(location=CAMP_COORDINATES, zoom_start=16)
folium.TileLayer("openstreetmap").add_to(map3)
# store the latitude and longitude coordinates from the data frame

for each in df3.iterrows():
        # for each MIRUID type we use a specific map symbol
        if each[1]['FAKEMIRUID']== 4:
            # unknown type: green circle
            unknowndr=folium.RegularPolygonMarker([each[1]['LAT'], \
                                                   each[1]['LON']], \
                                                  popup=each[1]['CaseNo'], \
                                                  fill_color='lightgreen', \
                                                  number_of_sides=12, \
                                                  radius=6).add_to(map3)
        if each[1]['FAKEMIRUID']== 3: 
            # pansusceptible type: blue circle
            Pansusceptible=folium.RegularPolygonMarker([each[1]['LAT'], \
                                                        each[1]['LON']], \
                                                       popup=each[1]['CaseNo'], \
                                                       fill_color='blue', \
                                                       number_of_sides=12, \
                                                       radius=6).add_to(map3)
        if each[1]['FAKEMIRUID']== 2:                     
            # resistant but not MDRTB: yellow square
            ResistantNotMDRTB=folium.RegularPolygonMarker([each[1]['LAT'], \
                                                           each[1]['LON']], \
                                                           popup=each[1]['CaseNo'], \
                                                          fill_color='yellow', \
                                                          number_of_sides=4, \
                                                          radius=8).add_to(map3)
        if each[1]['FAKEMIRUID']== 1:   
            # mdr-tb type: red triangle
            MDRTB=folium.RegularPolygonMarker([each[1]['LAT'], \
                                               each[1]['LON']], \
                                              popup=each[1]['CaseNo'], \
                                              fill_color='red', \
                                              number_of_sides=3, \
                                              radius=9).add_to(map3)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You have now created a map similar to that found on page 1718 of the Oeltmann et. al 2005 paper.
# <img src="./images/oeltmann_map.png">

# %% [markdown]
# You have been able to map the genotyped TB cases by drug resistance type within a refugee camp within Thailand. Please take some time to think about the questions at the end of this notebook and reflect upon the data requirements and purpose of this exercise. Thank you.

# %% [markdown]
# > Question 1: The TB case data provided in this exercise included the latitude and longitude coordinates gathered from GPS units. How critical are these geospatial data to completion of this exercise ?

# %% [markdown]
# ## Congratulations!

# %% [markdown]
# ## References

# %% [markdown]
# You have completed Notebook 2. Please proceed to Notebook 3.

# %% [markdown]
# CDC, 2017 Tuberculosis Genotyping: What is tuberculosis (TB) genotyping? CDC TB Fact Sheets 2017. URL: https://www.cdc.gov/tb/publications/factsheets/statistics/genotyping.htm
#
# CDC, 2017 GENType: New Genotyping Terminology to Integrate 24-locus MIRU-VNTR. CDC TB Fact Sheets 2017. URL: https://www.cdc.gov/tb/publications/factsheets/statistics/genotypingterminology.pdf
#
# CDC, 2017 A New Tool to Diagnose Tuberculosis: The Xpert MTB/RIF Assay. URL: https://www.cdc.gov/tb/publications/factsheets/pdf/xpertmtb-rifassayfactsheet_final.pdf
#
# Oeltmann, J. E., Varma, J. K., Ortega, L., Liu, Y., O’Rourke, T., Cano, M., … Maloney, S. A. (2008). Multidrug-Resistant Tuberculosis Outbreak among US-bound Hmong Refugees, Thailand, 2005. Emerging Infectious Diseases, 14(11), 1715–1721. http://doi.org/10.3201/eid1411.071629
#
# Shaw, N.S., et al. 2017. Transmission of Extensively Drug-Resistant Tuberculosis in South Africa. New England Journal of Medicine. January 19, 2017. 376:3.                                                  URL: http://www.nejm.org/doi/pdf/10.1056/NEJMoa1604544
#
# Additional readings:
# Reichmann, Lee B and Janice Hopkins Tanne. 2001. Timebomb: the global epidemic of multi-drug resistant tuberculosis. ISBN 0-07-135924-9. McGraw-Hill. URL: https://www.goodreads.com/book/show/1733578
